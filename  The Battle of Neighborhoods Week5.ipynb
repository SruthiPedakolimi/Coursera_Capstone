# %% [markdown]
# # The Battle of Neighbourhood

# %% [markdown]
# ###  Downloading and Importing Libraries

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.18.1-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  20.12 MB/s
# geopy-1.18.1-p 100% |################################| Time: 0:00:00  31.47 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  48.73 MB/s
# branca-0.3.1-p 100% |################################| Time: 0:00:00  26.32 MB/s
# vincent-0.4.4- 100% |################################| Time: 0:00:00  18.27 MB/s
# folium-0.5.0-p 100% |################################| Time: 0:00:00  22.53 MB/s
# Libraries imported.

# %% [markdown]
# ###  Scraping the Website using BeautifulSoup Package

# %%
#Getting the table from the website into the Dataframe

from bs4 import BeautifulSoup
import requests
import lxml.html as lh
import pandas as pd
import numpy as np
page_link='https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population'
page=requests.get(page_link)
soup=BeautifulSoup(page.content,'html.parser')
table_soup=soup.find_all('table')[4]
table = pd.read_html(str(table_soup))
df=pd.DataFrame(table[0])
df.columns=['Rank','City','State','Estimate','Census','Change','Land Area','Land Area2','population density1','Population Density','Location']
df.drop(columns=['Rank','Estimate','Census','Change','Land Area2','population density1'],inplace=True)
df=df.drop(0).reset_index(drop=True)

# %%
df.head()
# Out:
#           City       State    Land Area Population Density  \
# 0  New York[6]    New York  301.5 sq mi         10,933/km2
# 1  Los Angeles  California  468.7 sq mi          3,276/km2
# 2      Chicago    Illinois  227.3 sq mi          4,600/km2
# 3   Houston[7]       Texas  637.5 sq mi          1,395/km2
# 4      Phoenix     Arizona  517.6 sq mi          1,200/km2
#
#                                             Location
# 0  40°39′49″N 73°56′19″W﻿ / ﻿40.6635°N 73.9387°W﻿...
# 1  34°01′10″N 118°24′39″W﻿ / ﻿34.0194°N 118.4108°...
# 2  41°50′15″N 87°40′54″W﻿ / ﻿41.8376°N 87.6818°W﻿...
# 3  29°47′12″N 95°23′27″W﻿ / ﻿29.7866°N 95.3909°W﻿...
# 4  33°34′20″N 112°05′24″W﻿ / ﻿33.5722°N 112.0901°...

# %% [markdown]
# ### Seperating the Location Values into Latitudes and Longitudes

# %%
df['Location']=df['Location'].str.split("/",n=2,expand=True)[1]
new=df['Location'].str.split(" ",n=0,expand=False)
lat=[]
log=[]
for ind in range(len(new)):
    lat.append(new[ind][1][:-2])
    log.append(new[ind][2][:-3])
df['lat']=lat
df['log']=log
df.drop(columns=['Location'],inplace=True)
df.head()
# Out:
#           City       State    Land Area Population Density       lat       log
# 0  New York[6]    New York  301.5 sq mi         10,933/km2  ﻿40.6635   73.9387
# 1  Los Angeles  California  468.7 sq mi          3,276/km2  ﻿34.0194  118.4108
# 2      Chicago    Illinois  227.3 sq mi          4,600/km2  ﻿41.8376   87.6818
# 3   Houston[7]       Texas  637.5 sq mi          1,395/km2  ﻿29.7866   95.3909
# 4      Phoenix     Arizona  517.6 sq mi          1,200/km2  ﻿33.5722  112.0901

# %% [markdown]
# #### Converting the Land Area Column from str to float

# %%
import numpy as np
new=df['Land Area'].str.split("s",n=1,expand=True)
df['Land Area']=new[0].str.replace(u'\xa0',u'')
df['Land Area']=df['Land Area'].str.replace(',','').astype(float)
df['lat']=df['lat'].str.replace(u'\ufeff',u'').astype(float)
df['log']=-df['log'].str.replace(u'\ufeff',u'').astype(float)

# %%
df['Radius']=np.sqrt(df['Land Area']).round(2).mul(1000)
df.drop(columns=['Land Area'],inplace=True)

# %% [markdown]
# #####  FourSquare API Credentials

# %%
CLIENT_ID = '33MAOBUFOQV4JD2DRIVJP1DKT5WKB4DOYVRUFQPJDEL3BMPU' # your Foursquare ID
CLIENT_SECRET = 'BWJAUUER4DPCGCTA2GOFY1IB1RAEFCNWHDDFFW0QNUGQ5XGH' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 33MAOBUFOQV4JD2DRIVJP1DKT5WKB4DOYVRUFQPJDEL3BMPU
# CLIENT_SECRET:BWJAUUER4DPCGCTA2GOFY1IB1RAEFCNWHDDFFW0QNUGQ5XGH

# %% [markdown]
# ### Function to get the required attributes from the json file into a DataFrame

# %%
def getCityVenues(names,lat,log,radius):
    venues_list=[]
    for name,lat,log,radius in zip(names,lat,log,radius):
        LIMIT=150
        url='https://api.foursquare.com/v2/venues/explore?&client_id={0}&client_secret={1}&v={2}&ll={3},{4}&radius={5}&limit={6}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            log, 
            radius, 
            LIMIT)
        results = requests.get(url).json()['response']['groups'][0]['items']
        venues_list.append([(
            name,
            lat,
            log,
            v['venue']['name'],
            v['venue']['location']['lat'],
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venue=pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venue.columns=['City','Latitude','Logitude','Venue','Venue Latitude','Venue Longitude','Venue Category']
    return(nearby_venue)

# %%
city_venues=getCityVenues(df['City'],df['lat'],df['log'],df['Radius'])
city_venues.head()
# Out:
#           City  Latitude  Logitude                    Venue  Venue Latitude  \
# 0  New York[6]   40.6635  -73.9387               Barboncino       40.672104
# 1  New York[6]   40.6635  -73.9387  Brooklyn Botanic Garden       40.667884
# 2  New York[6]   40.6635  -73.9387               Covenhoven       40.675143
# 3  New York[6]   40.6635  -73.9387          Brooklyn Museum       40.671069
# 4  New York[6]   40.6635  -73.9387            Kings Theatre       40.646110
#
#    Venue Longitude    Venue Category
# 0       -73.957412       Pizza Place
# 1       -73.963587  Botanical Garden
# 2       -73.960203       Beer Garden
# 3       -73.963619        Art Museum
# 4       -73.957175           Theater

# %% [markdown]
# ### Adding the Weightage Column to the selected Venue Category in city_venues dataframe

# %%
weightage_dict={'Movie Theater':3,'Beach':3,'Concert Hall':2.5,'Playground':3,'Coffee Shop':3.5,'Food Court':4,'Nightclub':4,'Toy / Game Store':4.5,'Theme Park Ride / Attraction':4,'Pub':4,'Others':0}

def get_weightage(category_dataframe,weights_dict=weightage_dict):
    
    weightage_list=[]
    for cat in category_dataframe:
        if cat in weights_dict.keys():
            weightage_list.append(weights_dict[cat])
        else:
            cat='Others'
            weightage_list.append(weights_dict[cat])
    return weightage_list

# %%
city_venues['weightage']=get_weightage(city_venues['Venue Category'],weightage_dict) 
city_venues=city_venues[city_venues['weightage']!=0.0]

# %%
df_venues=city_venues[['City','weightage']]
df_venues=df_venues.groupby(['City'],axis=0).mean()
df_venues.reset_index(drop=False,inplace=True)

# %%
df_venues.head()
# Out:
#              City  weightage
# 0         Abilene   3.416667
# 1           Akron   3.600000
# 2     Albuquerque   3.500000
# 3  Alexandria[16]   3.500000
# 4           Allen   3.312500

# %%
df_data=pd.merge(df_venues,df,on='City')
df_data.drop(columns=['State','Radius','lat','log'],inplace=True)

# %%
km_split=df_data['Population Density'].str.split("/",n=1,expand=True)
df_data['Population Density']=km_split[0].str.replace(',','')
df_data['Population Density']=df_data['Population Density'].astype(float)

# %%
df_data.head()
# Out:
#              City  weightage  Population Density
# 0         Abilene   3.416667               442.0
# 1           Akron   3.600000              1231.0
# 2     Albuquerque   3.500000              1147.0
# 3  Alexandria[16]   3.500000              4010.0
# 4           Allen   3.312500              1434.0

# %% [markdown]
# ### Normalizing the selected columns in the DataFrame

# %%
from sklearn import preprocessing


normalize_columns=['weightage','Population Density']

x=df_data[normalize_columns].values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_data[normalize_columns]=pd.DataFrame(x_scaled)
df_data.head()
# Out:
#              City  weightage  Population Density
# 0         Abilene   0.528455            0.034422
# 1           Akron   0.707317            0.107041
# 2     Albuquerque   0.609756            0.099310
# 3  Alexandria[16]   0.609756            0.362816
# 4           Allen   0.426829            0.125725

# %% [markdown]
# #### Calculating the sum of the normalized columns and getting the City having the maximum sum value

# %%
df_data['Sum']=df_data['weightage']+df_data['Population Density']

# %%
df_data.loc[df_data['Sum'].idxmax()]
# Out:
# City                  Cambridge
# weightage              0.853659
# Population Density     0.608099
# Sum                     1.46176
# Name: 35, dtype: object

# %% [markdown]
# ##### Here the city __"Cambridge"__ has the maximum sum value. So we will select the City Cambridge

# %% [markdown]
# ### Getting the nearby Venues from the Cambridge City from the FourSquareAPI

# %%
city_latitude=df.loc[df['City']=='Cambridge','lat'].item()
city_longitude=df.loc[df['City']=='Cambridge','log'].item()
radius=5000
LIMIT=500

# %%
def getCambridgeCityVenues(lat,log):
    venues_list=[]
    radius=5000
    LIMIT=150
    url='https://api.foursquare.com/v2/venues/explore?&client_id={0}&client_secret={1}&v={2}&ll={3},{4}&radius={5}&limit={6}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        log, 
        radius, 
        LIMIT)
    results = requests.get(url).json()['response']['groups'][0]['items']
    venues_list.append([(
        v['venue']['location']['city'],
        v['venue']['name'],
        v['venue']['location']['lat'],
        v['venue']['location']['lng'],
        v['venue']['categories'][0]['name']) for v in results])
    nearby_venue=pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venue.columns=['City','Venue','Venue Latitude','Venue Longitude','Venue Category']
    return(nearby_venue)

# %%
cambridge_venues=getCambridgeCityVenues(city_latitude,city_longitude)

# %%
final_venues=cambridge_venues[cambridge_venues['City']=='Cambridge']

# %%
final_venues.reset_index(drop=True)
# Out:
#          City                                        Venue  Venue Latitude  \
# 0   Cambridge                               Harvard Square       42.373501
# 1   Cambridge                    Felipe's Mexican Taqueria       42.373431
# 2   Cambridge                           Harvard Book Store       42.372708
# 3   Cambridge                              Sanders Theatre       42.375835
# 4   Cambridge                                 The Sinclair       42.374094
# 5   Cambridge                              Brattle Theatre       42.373538
# 6   Cambridge                          Harvard Art Museums       42.374206
# 7   Cambridge                          Flour Bakery + Cafe       42.373117
# 8   Cambridge                       L.A. Burdick Chocolate       42.374456
# 9   Cambridge                               Alden & Harlow       42.373572
# 10  Cambridge            Harvard Museum of Natural History       42.378410
# 11  Cambridge                    Loeb Drama Center (A.R.T)       42.374968
# 12  Cambridge                                      Orinoco       42.371933
# 13  Cambridge                          Tatte Bakery & Cafe       42.372795
# 14  Cambridge                         Russell House Tavern       42.373138
# 15  Cambridge  Peabody Museum of Archaeology and Ethnology       42.378146
# 16  Cambridge                                   J.P. Licks       42.372989
# 17  Cambridge                     Pinocchio's Pizza & Subs       42.371946
# 18  Cambridge                                Darwin's Ltd.       42.374928
# 19  Cambridge                                   Zinneken's       42.371232
# 20  Cambridge                                   Cafe Sushi       42.370616
# 21  Cambridge                                       Giulia       42.382511
# 22  Cambridge                                     Waypoint       42.369640
# 23  Cambridge                                      Pammy's       42.368493
# 24  Cambridge                               Dumpling House       42.368930
# 25  Cambridge                            Formaggio Kitchen       42.381433
# 26  Cambridge                                  Inman Oasis       42.374264
# 27  Cambridge                        Hi-Rise Bread Company       42.382520
# 28  Cambridge                                   Life Alive       42.366640
# 29  Cambridge                          Porter Square Books       42.389600
# 30  Cambridge                                      Rod Dee       42.388861
# 31  Cambridge                                    The Druid       42.373690
# 32  Cambridge                     Alive & Kicking Lobsters       42.362573
# 33  Cambridge                               The Coast Café       42.362947
# 34  Cambridge                                       Oleana       42.370658
# 35  Cambridge                             Prana Power Yoga       42.364926
# 36  Cambridge                      Lamplighter Brewing Co.       42.367972
# 37  Cambridge                               Brick & Mortar       42.364924
# 38  Cambridge                           Longfellows Coffee       42.368050
# 39  Cambridge              Pemberton Farms & Garden Center       42.393787
# 40  Cambridge                                Veggie Galaxy       42.363689
# 41  Cambridge                                Darwin's Ltd.       42.362402
# 42  Cambridge                                    Lord Hobo       42.368784
# 43  Cambridge                  iLoveKickboxing - Cambridge       42.388351
# 44  Cambridge                              Craigie on Main       42.363372
# 45  Cambridge                            Izzy's Restaurant       42.366181
# 46  Cambridge                                  Cuchi Cuchi       42.363321
# 47  Cambridge                              Atwood’s Tavern       42.372576
# 48  Cambridge                   Mulan Taiwanese Restaurant       42.366614
# 49  Cambridge                          Flour Bakery + Cafe       42.361025
# 50  Cambridge                          Flour Bakery + Cafe       42.357778
# 51  Cambridge                                    Mamaleh's       42.365933
# 52  Cambridge                          Sofra Bakery & Cafe       42.374735
# 53  Cambridge                                    Area Four       42.363073
# 54  Cambridge                        Kendall Square Cinema       42.367676
# 55  Cambridge                              Season To Taste       42.398362
# 56  Cambridge                           Lone Star Taco Bar       42.372038
# 57  Cambridge            Zesiger Sports And Fitness Center       42.358802
# 58  Cambridge                       Fresh Pond Reservation       42.387275
# 59  Cambridge                    Iggy's Bread of the World       42.393348
#
#     Venue Longitude                   Venue Category
# 0        -71.119098                            Plaza
# 1        -71.120515               Mexican Restaurant
# 2        -71.116464                        Bookstore
# 3        -71.114786                          Theater
# 4        -71.120757                        Rock Club
# 5        -71.121291              Indie Movie Theater
# 6        -71.114368                       Art Museum
# 7        -71.122349                           Bakery
# 8        -71.121906                             Café
# 9        -71.121319          New American Restaurant
# 10       -71.115720                   Science Museum
# 11       -71.122686                          Theater
# 12       -71.120612                 Arepa Restaurant
# 13       -71.116966                             Café
# 14       -71.119512                        Gastropub
# 15       -71.114734                   History Museum
# 16       -71.117502                   Ice Cream Shop
# 17       -71.120237                      Pizza Place
# 18       -71.109394                   Sandwich Place
# 19       -71.114483                   Breakfast Spot
# 20       -71.113385                 Sushi Restaurant
# 21       -71.119709               Italian Restaurant
# 22       -71.111985          New American Restaurant
# 23       -71.109078                       Restaurant
# 24       -71.109977              Dumpling Restaurant
# 25       -71.133816                      Cheese Shop
# 26       -71.100952                              Spa
# 27       -71.131325                           Bakery
# 28       -71.105635    Vegetarian / Vegan Restaurant
# 29       -71.118875                        Bookstore
# 30       -71.119936                  Thai Restaurant
# 31       -71.100303                              Pub
# 32       -71.113804               Seafood Restaurant
# 33       -71.111524  Southern / Soul Food Restaurant
# 34       -71.097168         Mediterranean Restaurant
# 35       -71.102815                      Yoga Studio
# 36       -71.097962                          Brewery
# 37       -71.102373                     Cocktail Bar
# 38       -71.097899                      Coffee Shop
# 39       -71.125722                  Organic Grocery
# 40       -71.101055    Vegetarian / Vegan Restaurant
# 41       -71.098514                   Sandwich Place
# 42       -71.094845                        Gastropub
# 43       -71.141606             Gym / Fitness Center
# 44       -71.098726          New American Restaurant
# 45       -71.095754        Latin American Restaurant
# 46       -71.097095                           Lounge
# 47       -71.091450          Comfort Food Restaurant
# 48       -71.094196             Taiwanese Restaurant
# 49       -71.096646                           Bakery
# 50       -71.104177                           Bakery
# 51       -71.091180                Jewish Restaurant
# 52       -71.150385                           Bakery
# 53       -71.092459                      Pizza Place
# 54       -71.090169                    Movie Theater
# 55       -71.131089                           Bistro
# 56       -71.086961                       Taco Place
# 57       -71.095888             Gym / Fitness Center
# 58       -71.147083                             Lake
# 59       -71.148092                           Bakery

# %%
weights={'Plaza':3,'Rock Club':3.5,'Theater':3.5,'Pub':4,'Cocktail Bar':3.8,'Movie Theater':3.5,'Others':0,'Bookstore':1.5,'Indie Movie Theater':2.5,'Café':3,'Pizza Place':2.5,'Sandwich Place':2.5,'Coffee Shop':3.5}

# %% [markdown]
# ### Plotting the Cambridge City and the City Venues

# %%
#visualisation of cabridge City and the Venues of the City
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium

map_venue=folium.Map(location=[city_latitude,city_longitude],zoom_start=15)
folium.features.CircleMarker(
   [city_latitude, city_longitude],
   radius=10,
   popup='Cambridge City',
   fill=True,
   color='red',
   fill_color='red',
   fill_opacity=0.6
   ).add_to(map_venue)

for lat,lng,label in zip(cambridge_venues['Venue Latitude'],cambridge_venues['Venue Longitude'],cambridge_venues['Venue']):
    label=folium.Popup(label,parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_venue)
map_venue
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Adding the Weightage column for the selected categories

# %%
final_venues['weightage']=get_weightage(final_venues['Venue Category'],weights_dict=weights)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
cambridge_final_data=final_venues[final_venues['weightage']!=0.0]

# %%
cambridge_final_data.reset_index(drop=True,inplace=True)

# %%
cambridge_final_data.head()
# Out:
#         City               Venue  Venue Latitude  Venue Longitude  \
# 0  Cambridge      Harvard Square       42.373501       -71.119098
# 1  Cambridge  Harvard Book Store       42.372708       -71.116464
# 2  Cambridge     Sanders Theatre       42.375835       -71.114786
# 3  Cambridge        The Sinclair       42.374094       -71.120757
# 4  Cambridge     Brattle Theatre       42.373538       -71.121291
#
#         Venue Category  weightage
# 0                Plaza        3.0
# 1            Bookstore        1.5
# 2              Theater        3.5
# 3            Rock Club        3.5
# 4  Indie Movie Theater        2.5

# %% [markdown]
# ### Applying K Means for the Attributes Venue Latitude and Venue Longitude

# %%
from sklearn.cluster import KMeans

kclusters = 5
cambridge_grouped_clustering = cambridge_final_data.drop(columns=['City','Venue','Venue Category','weightage'])
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(cambridge_grouped_clustering)
kmeans.labels_
# Out:
# array([3, 1, 1, 3, 3, 3, 3, 1, 3, 1, 2, 0, 0, 0, 0, 4, 4], dtype=int32)

# %%
cambridge_final_data['Cluster Labels']=kmeans.labels_
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
cambridge_final_data.head()
# Out:
#         City               Venue  Venue Latitude  Venue Longitude  \
# 0  Cambridge      Harvard Square       42.373501       -71.119098
# 1  Cambridge  Harvard Book Store       42.372708       -71.116464
# 2  Cambridge     Sanders Theatre       42.375835       -71.114786
# 3  Cambridge        The Sinclair       42.374094       -71.120757
# 4  Cambridge     Brattle Theatre       42.373538       -71.121291
#
#         Venue Category  weightage  Cluster Labels
# 0                Plaza        3.0               3
# 1            Bookstore        1.5               1
# 2              Theater        3.5               1
# 3            Rock Club        3.5               3
# 4  Indie Movie Theater        2.5               3

# %% [markdown]
# ### Grouping Based on the Cluster Labels and calculating the weightage Sum

# %%
cluster_group=cambridge_final_data.groupby(['Cluster Labels'])['weightage'].sum()

# %%
cluster_group
# Out:
# Cluster Labels
# 0    13.8
# 1    10.5
# 2     1.5
# 3    18.0
# 4     6.0
# Name: weightage, dtype: float64

# %%
arcade_location=kmeans.cluster_centers_[3].tolist()
arcade_location
# Out:
# [42.37375037888433, -71.12099559190885]

# %% [markdown]
# ### The above results shows that the cluster 3 has more weightage so we will choose that coordinates as the Clients First Arcade in that City

# %%
#visualisation of cambridge
import matplotlib.cm as cm
import matplotlib.colors as colors
import folium

map_venue=folium.Map(location=[arcade_location[0],arcade_location[1]],zoom_start=11)
folium.features.CircleMarker(
   [city_latitude, city_longitude],
   radius=50,
   popup='Our Arcade',
   fill=True,
   color='red',
   fill_color='red',
   fill_opacity=0.6
   ).add_to(map_venue)

for lat,lng,label in zip(cambridge_final_data['Venue Latitude'],cambridge_final_data['Venue Longitude'],cambridge_final_data['Venue Category']):
    label=folium.Popup(label,parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=10,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_venue)
map_venue
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
